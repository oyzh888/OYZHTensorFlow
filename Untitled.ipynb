# %%
x = [1,2,3]
for val in x:
    if val == 1 or 2 or 3:
        print x
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# Tensor("Placeholder_21:0", shape=(?, 10), dtype=float32)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ea46145b14e3> in <module>()
#       7 tf.global_variables_initializer().run()
#       8 for _ in range(1000):
# ----> 9     batch_xs, batch_ys = mnist.train.next_batch(100)
#      10     sess.run(train_step, feed_dict={x: batch_xs, y_: batch_ys})
#      11
#
# NameError: name 'mnist' is not defined
